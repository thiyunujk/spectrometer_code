# %%
import os
import pandas as pd

def process_text_file(file_path):
    # Read the text file
    with open(file_path, 'r') as file:
        lines = file.readlines()

    # Take the total count of all rows in the file
    total_rows = len(lines)
    print(total_rows)

    # Remove lines after 2720 row
    lines = lines[:2720]

    # Take the rest of the rows and remove the first 1103 rows
    processed_lines = lines[1103:]

    # Create a DataFrame with a single column 'features'
    df = pd.DataFrame({"features": [float(value) for line in processed_lines for value in line.split()[1:]]})

    # Add a new column 'class' with the value "raw"
    df['class'] = 'raw'

    # Convert the DataFrame to an Excel file
    excel_file_path = file_path.replace('.txt', '.xlsx')
    df.to_excel(excel_file_path, index=False)

if __name__ == "__main__":
    # Replace 'input_folder' with the path to your folder containing the text files
    input_folder = r'C:\Users\jk\Desktop\piGUI\spectrometer_code\data_set_preparation\ai spectro\raw sample 1'

    # Process each text file in the folder
    for filename in os.listdir(input_folder):
        if filename.endswith('.txt'):
            file_path = os.path.join(input_folder, filename)
            process_text_file(file_path)
# Out:
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
# 3648
